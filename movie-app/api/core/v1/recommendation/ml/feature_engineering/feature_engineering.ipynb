# %% [markdown]
# # Imports usados nesse notebook

# %%
import numpy as np
from numpy import ma
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import keras
from api.core.v1.recommendation.ml.utils import generate_subset_movies_not_rated, load_data, gen_user_vecs, sq_dist, get_pred_movies, genres

# %% [markdown]
# # Carregar os dados

# %%
item_set, user_set, y_set, movies_dict, df_movie_rating, df_movie_rating_user_avg = load_data()
# Out:
# INFO:api.core.v1.recommendation.ml.utils:loading and transforming data...
# INFO:api.core.v1.recommendation.ml.utils:done loading data.

# %% [markdown]
# # Transform dos dados, parametrização e treino do modelo

# %%
# configs

num_user_features = user_set.shape[1] - 3  # remover userid, rating count and ave rating durante o treino
num_item_features = item_set.shape[1] - 1  # remover movie id durante o treino

# indices auxiliares
user_vector_start = 3
item_vector_start = 3
user_columns_start = 3
item_columns_start = 1

# %%
# transformar os dados

scalerItem = StandardScaler()
scalerItem.fit(item_set)
item_set = scalerItem.transform(item_set)

scalerUser = StandardScaler()
scalerUser.fit(user_set)
user_set = scalerUser.transform(user_set)

scalerTarget = MinMaxScaler((-1, 1))
scalerTarget.fit(y_set.reshape(-1, 1))
y_set = scalerTarget.transform(y_set.reshape(-1, 1))

# %%
# separar em treino e teste

item_train, item_test = train_test_split(item_set, train_size=0.70, shuffle=True, random_state=1)
user_train, user_test = train_test_split(user_set, train_size=0.70, shuffle=True, random_state=1)
y_train, y_test = train_test_split(y_set, train_size=0.70, shuffle=True, random_state=1)

# %%
# definicao das NNs

# criar os inputs
input_user = keras.layers.Input(shape=(num_user_features,))
input_item = keras.layers.Input(shape=(num_item_features,))


user_NN = keras.models.Sequential([
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(32, activation='linear'),
])

item_NN = keras.models.Sequential([
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(32, activation='linear'),
])


# direcionar para as NNs
vu = user_NN(input_user)
vu = keras.layers.LayerNormalization(axis=1)(vu)

vm = item_NN(input_item)
vm = keras.layers.LayerNormalization(axis=1)(vm)

output = keras.layers.Dot(axes=1)([vu, vm])

# especificar o input e o output do modelo
model = keras.Model([input_user, input_item], output)

# hiperparametros
cost_fn = keras.losses.MeanSquaredError()
opt = keras.optimizers.Adam(learning_rate=0.1)

model.compile(optimizer=opt,
            loss=cost_fn)

# %%
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 14)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, 16)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 32)        │     40,864 │ input_layer_4[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, 32)        │     41,376 │ input_layer_5[0]… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32)        │         64 │ sequential_2[0][… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32)        │         64 │ sequential_3[0][… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot_1 (Dot)         │ (None, 1)         │          0 │ layer_normalizat… │
# │                     │                   │            │ layer_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 82,368 (321.75 KB)
#  Trainable params: 82,368 (321.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit([user_train[:, user_columns_start:], item_train[:, item_columns_start:]], y_train, epochs=30)
# Out:
# Epoch 1/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 30.1212
# Epoch 2/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5111
# Epoch 3/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5281
# Epoch 4/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4955
# Epoch 5/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4928
# Epoch 6/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5161
# Epoch 7/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5052
# Epoch 8/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4930
# Epoch 9/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5052
# Epoch 10/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5092
# Epoch 11/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4937
# Epoch 12/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5104
# Epoch 13/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4948
# Epoch 14/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5018
# Epoch 15/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4990
# Epoch 16/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4938
# Epoch 17/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4897
# Epoch 18/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4976
# Epoch 19/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4907
# Epoch 20/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5020
# Epoch 21/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4918
# Epoch 22/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4931
# Epoch 23/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4933
# Epoch 24/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4906
# Epoch 25/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4926
# Epoch 26/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4999
# Epoch 27/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4968
# Epoch 28/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5011
# Epoch 29/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4977
# Epoch 30/30
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4987

# %%
model.evaluate([user_test[:, user_columns_start:], item_test[:, item_columns_start:]], y_test)
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.4997
# 0.5144850611686707

# %% [markdown]
# # Predict de um item baseado em um novo user

# %%
new_user_id = 5000
new_rating_ave = 0.0
new_action = 0.0
new_adventure = 5.0
new_animation = 0.0
new_childrens = 0.0
new_comedy = 0.0
new_crime = 0.0
new_documentary = 0.0
new_drama = 0.0
new_fantasy = 5.0
new_horror = 0.0
new_mystery = 0.0
new_romance = 0.0
new_scifi = 0.0
new_thriller = 0.0
new_rating_count = 3

new_user_vec = np.array([[new_user_id, new_rating_count, new_rating_ave,
                      new_action, new_adventure, new_animation, new_childrens,
                      new_comedy, new_crime, new_documentary,
                      new_drama, new_fantasy, new_horror, new_mystery,
                      new_romance, new_scifi, new_thriller]])

# %%
item_vecs = generate_subset_movies_not_rated(new_user_id, df_movie_rating, df_movie_rating_user_avg, min_imdb_rating=3.0)

# gerar o vetor de users para ser do mesmo tamanho do item_vecs
user_vecs = gen_user_vecs(new_user_vec, len(item_vecs))

# transformar os valores
suser_vecs = scalerUser.transform(user_vecs)
sitem_vecs = scalerItem.transform(item_vecs)

# predição
y_p = model.predict([suser_vecs[:, user_columns_start:], sitem_vecs[:, item_columns_start:]])
y_pu = scalerTarget.inverse_transform(y_p)


sorted_index = np.argsort(-y_pu,axis=0).reshape(-1).tolist()
sorted_ypu = y_pu[sorted_index]
sorted_items = item_vecs[sorted_index]


df_new_user = get_pred_movies(sorted_ypu, sorted_items, movies_dict, maxcount = 50)
df_new_user.head()
# Out:
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
#    y_p  movie id  rating ave  \
# 0  4.4      3471         2.4
# 1  4.4      1306         2.5
# 2  4.4      4370         2.5
# 3  4.4       924         2.3
# 4  4.3      8591         2.2
#
#                                                title                  genres
# 0          Close Encounters of the Third Kind (1977)  Adventure|Drama|Sci-Fi
# 1  Until the End of the World (Bis ans Ende der W...  Adventure|Drama|Sci-Fi
# 2                A.I. Artificial Intelligence (2001)  Adventure|Drama|Sci-Fi
# 3                       2001: A Space Odyssey (1968)  Adventure|Drama|Sci-Fi
# 4                Philadelphia Experiment, The (1984)  Adventure|Drama|Sci-Fi

# %%
df_new_user[["title", "genres"]].to_dict()
# Out:
# {'title': {0: 'Close Encounters of the Third Kind (1977)',
#   1: 'Until the End of the World (Bis ans Ende der Welt) (1991)',
#   2: 'A.I. Artificial Intelligence (2001)',
#   3: '2001: A Space Odyssey (1968)',
#   4: 'Philadelphia Experiment, The (1984)',
#   5: 'Star Trek: Generations (1994)',
#   6: 'WarGames (1983)',
#   7: 'Millennium (1989)',
#   8: "Man Escaped, A (Un  condamné à mort s'est échappé ou Le vent souffle où il veut) (1956)",
#   9: 'Lawrence of Arabia (1962)',
#   10: 'Fountain, The (2006)',
#   11: 'Almost Heroes (1998)',
#   12: 'Beautiful Creatures (2013)',
#   13: 'Walkabout (1971)',
#   14: 'Nothing But Trouble (1991)',
#   15: 'Like Water for Chocolate (Como agua para chocolate) (1992)',
#   16: 'Gattaca (1997)',
#   17: 'Beastly (2011)',
#   18: 'About Time (2013)',
#   19: 'Captains Courageous (1937)',
#   20: 'Dersu Uzala (1975)',
#   21: 'Double Life of Veronique, The (Double Vie de Véronique, La) (1991)',
#   22: 'Let the Right One In (Låt den rätte komma in) (2008)',
#   23: 'Big Fish (2003)',
#   24: 'Twilight (2008)',
#   25: 'Wristcutters: A Love Story (2006)',
#   26: 'Penn & Teller Get Killed (1989)',
#   27: 'Orlando (1992)',
#   28: 'Fitzcarraldo (1982)',
#   29: 'Deliverance (1972)',
#   30: 'Tenacious D in The Pick of Destiny (2006)',
#   31: 'Quest for Fire (Guerre du feu, La) (1981)',
#   32: "Weekend at Bernie's II (1993)",
#   33: 'Galaxy Quest (1999)',
#   34: 'Back to the Future Part III (1990)',
#   35: 'Bounty, The (1984)',
#   36: 'Maverick (1994)',
#   37: 'Treasure of the Sierra Madre, The (1948)',
#   38: 'Norte, El (1984)',
#   39: 'No Such Thing (2001)',
#   40: 'Return to Snowy River (a.k.a. The Man From Snowy River II) (1988)',
#   41: 'Land That Time Forgot, The (1975)',
#   42: "Money Money Money (L'aventure, c'est l'aventure) (1972)",
#   43: 'Ben-Hur (1959)',
#   44: 'Mutiny on the Bounty (1935)',
#   45: 'THX 1138 (1971)',
#   46: 'Guns of Navarone, The (1961)',
#   47: 'Lovely Bones, The (2009)',
#   48: "My Father's Glory (La gloire de mon père) (1990)",
#   49: 'Captain Phillips (2013)'},
#  'genres': {0: 'Adventure|Drama|Sci-Fi',
#   1: 'Adventure|Drama|Sci-Fi',
#   2: 'Adventure|Drama|Sci-Fi',
#   3: 'Adventure|Drama|Sci-Fi',
#   4: 'Adventure|Drama|Sci-Fi',
#   5: 'Adventure|Drama|Sci-Fi',
#   6: 'Drama|Sci-Fi|Thriller',
#   7: 'Drama|Sci-Fi|Thriller',
#   8: 'Adventure|Drama',
#   9: 'Adventure|Drama|War',
#   10: 'Drama|Fantasy|Romance',
#   11: 'Adventure|Comedy|Western',
#   12: 'Drama|Fantasy|Romance',
#   13: 'Adventure|Drama',
#   14: 'Adventure|Comedy',
#   15: 'Drama|Fantasy|Romance',
#   16: 'Drama|Sci-Fi|Thriller',
#   17: 'Drama|Fantasy|Romance',
#   18: 'Drama|Fantasy|Romance',
#   19: 'Adventure|Drama',
#   20: 'Adventure|Drama',
#   21: 'Drama|Fantasy|Romance',
#   22: 'Drama|Fantasy|Horror|Romance',
#   23: 'Drama|Fantasy|Romance',
#   24: 'Drama|Fantasy|Romance|Thriller',
#   25: 'Drama|Fantasy|Romance',
#   26: 'Adventure|Comedy',
#   27: 'Drama|Fantasy|Romance',
#   28: 'Adventure|Drama',
#   29: 'Adventure|Drama|Thriller',
#   30: 'Adventure|Comedy|Musical',
#   31: 'Adventure|Drama',
#   32: 'Adventure|Comedy',
#   33: 'Adventure|Comedy|Sci-Fi',
#   34: 'Adventure|Comedy|Sci-Fi|Western',
#   35: 'Adventure|Drama',
#   36: 'Adventure|Comedy|Western',
#   37: 'Action|Adventure|Drama|Western',
#   38: 'Adventure|Drama',
#   39: 'Drama|Fantasy|Romance',
#   40: 'Adventure|Drama|Western',
#   41: 'Adventure|Sci-Fi',
#   42: 'Adventure|Comedy',
#   43: 'Action|Adventure|Drama',
#   44: 'Adventure|Drama',
#   45: 'Action|Adventure|Drama|Sci-Fi',
#   46: 'Action|Adventure|Drama|War',
#   47: 'Crime|Drama|Fantasy|Horror|Thriller',
#   48: 'Adventure|Drama',
#   49: 'Adventure|Drama|Thriller|IMAX'}}

# %% [markdown]
# # Predict de um item baseado em um user existente

# %%
user_id = 52
# agrupa os filmes avaliados com os generos
df_movie_rating_user_avg_genres = df_movie_rating.groupby(["rater_id", "title"] + genres)["rating"].mean()
df_movie_rating_user_avg_genres = df_movie_rating_user_avg_genres.loc[user_id].reset_index()
rating_count = df_movie_rating_user_avg_genres.value_counts().sum()
rating_ave = df_movie_rating_user_avg_genres["rating"].mean()
user_vec = [user_id, rating_count, rating_ave] + [df_movie_rating_user_avg_genres[df_movie_rating_user_avg_genres[genre] == 1]["rating"].mean() for genre in genres]

item_vecs = generate_subset_movies_not_rated(user_id, df_movie_rating, df_movie_rating_user_avg, min_imdb_rating=3.0)

# gerar o vetor de users para ser do mesmo tamanho do item_vecs
user_vecs = gen_user_vecs(user_vec, len(item_vecs))

# transformar os valores
suser_vecs = scalerUser.transform(user_vecs)
sitem_vecs = scalerItem.transform(item_vecs)

# predição
y_p = model.predict([suser_vecs[:, user_columns_start:], sitem_vecs[:, item_columns_start:]])
y_pu = scalerTarget.inverse_transform(y_p)


sorted_index = np.argsort(-y_pu,axis=0).reshape(-1).tolist()
sorted_ypu   = y_pu[sorted_index]
sorted_items = item_vecs[sorted_index]


df = get_pred_movies(sorted_ypu, sorted_items, movies_dict, maxcount = 50)
df
# Out:
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#     y_p  movie id  rating ave  \
# 0   4.1     97938         2.3
# 1   4.1     80839         2.3
# 2   4.1    105197         2.4
# 3   4.1      1615         2.3
# 4   4.1       155         2.3
# 5   4.1     35015         2.2
# 6   4.1      1027         2.4
# 7   4.1      5839         2.5
# 8   4.1      4534         2.4
# 9   4.1    110127         2.6
# 10  4.1     61026         2.6
# 11  4.1    105504         2.3
# 12  4.1    117192         2.1
# 13  4.1    132462         2.5
# 14  4.1      5446         2.1
# 15  4.1      4000         2.5
# 16  4.1     26649         2.2
# 17  4.1    101884         2.2
# 18  4.1      8905         2.2
# 19  4.1      6162         2.1
# 20  4.1      8832         2.6
# 21  4.1      5358         2.3
# 22  4.1     73321         2.5
# 23  4.1      4142         2.8
# 24  4.1     26472         2.2
# 25  4.1      8640         2.5
# 26  4.1     92234         2.4
# 27  4.1      5361         2.3
# 28  4.1      5357         2.3
# 29  4.1      2477         2.4
# 30  4.1      4988         2.3
# 31  4.1     95717         2.3
# 32  4.1      7143         2.5
# 33  4.1    136912         2.4
# 34  4.1      3036         2.2
# 35  4.1     55247         2.4
# 36  4.1      3347         2.2
# 37  4.1    155774         2.4
# 38  4.1     89087         2.4
# 39  4.1      3578         2.4
# 40  4.1       340         2.0
# 41  4.1     82765         2.7
# 42  4.1      3470         2.3
# 43  4.1      4818         2.4
# 44  4.1      6721         2.4
# 45  4.1       150         2.0
# 46  4.1     91485         2.8
# 47  4.1      1884         2.2
# 48  4.1        86         2.3
# 49  4.1      2421         2.4
#
#                                                 title  \
# 0                                   Life of Pi (2012)
# 1                                  Secretariat (2010)
# 2                                     Nebraska (2013)
# 3                                    Edge, The (1997)
# 4                               Beyond Rangoon (1995)
# 5                                         Duma (2005)
# 6                Robin Hood: Prince of Thieves (1991)
# 7    My Father's Glory (La gloire de mon père) (1990)
# 8   Return to Snowy River (a.k.a. The Man From Sno...
# 9                                         Noah (2014)
# 10                          Red Cliff (Chi bi) (2008)
# 11                            Captain Phillips (2013)
# 12          Doctor Who: The Time of the Doctor (2013)
# 13                          Sword of Vengeance (2014)
# 14                          Rabbit-Proof Fence (2002)
# 15                                 Bounty, The (1984)
# 16                               Lonesome Dove (1989)
# 17                                   Dark Tide (2012)
# 18                  1492: Conquest of Paradise (1992)
# 19                                       Gerry (2002)
# 20  Warriors of Heaven and Earth (Tian di ying xio...
# 21                       Mountains of the Moon (1990)
# 22                            Book of Eli, The (2010)
# 23                      Left Behind: The Movie (2000)
# 24                                   Norte, El (1984)
# 25                                 King Arthur (2004)
# 26                                   Red Tails (2012)
# 27                                  White Fang (1991)
# 28                                   Iron Will (1994)
# 29                                  Firewalker (1986)
# 30                          White Water Summer (1987)
# 31                             Treasure Island (2012)
# 32                           Last Samurai, The (2003)
# 33                            God Loves Caviar (2012)
# 34          Quest for Fire (Guerre du feu, La) (1981)
# 35                               Into the Wild (2007)
# 36                              Never Cry Wolf (1983)
# 37                                   Neon Bull (2015)
# 38                                  Colombiana (2011)
# 39                                   Gladiator (2000)
# 40                                    War, The (1994)
# 41     Little Big Soldier (Da bing xiao jiang) (2010)
# 42                                 Dersu Uzala (1975)
# 43                                Extreme Days (2001)
# 44   Once Upon a Time in China (Wong Fei Hung) (1991)
# 45                                   Apollo 13 (1995)
# 46                          Expendables 2, The (2012)
# 47              Fear and Loathing in Las Vegas (1998)
# 48                                White Squall (1996)
# 49                    Karate Kid, Part II, The (1986)
#
#                                genres
# 0                Adventure|Drama|IMAX
# 1                     Adventure|Drama
# 2                     Adventure|Drama
# 3                     Adventure|Drama
# 4                 Adventure|Drama|War
# 5                     Adventure|Drama
# 6                     Adventure|Drama
# 7                     Adventure|Drama
# 8             Adventure|Drama|Western
# 9                Adventure|Drama|IMAX
# 10         Action|Adventure|Drama|War
# 11      Adventure|Drama|Thriller|IMAX
# 12                    Adventure|Drama
# 13             Action|Adventure|Drama
# 14                    Adventure|Drama
# 15                    Adventure|Drama
# 16            Adventure|Drama|Western
# 17           Adventure|Drama|Thriller
# 18                    Adventure|Drama
# 19                    Adventure|Drama
# 20             Action|Adventure|Drama
# 21                          Adventure
# 22             Action|Adventure|Drama
# 23    Action|Adventure|Drama|Thriller
# 24                    Adventure|Drama
# 25         Action|Adventure|Drama|War
# 26         Action|Adventure|Drama|War
# 27                          Adventure
# 28                          Adventure
# 29                          Adventure
# 30                          Adventure
# 31                          Adventure
# 32         Action|Adventure|Drama|War
# 33                          Adventure
# 34                    Adventure|Drama
# 35             Action|Adventure|Drama
# 36                    Adventure|Drama
# 37                          Adventure
# 38    Action|Adventure|Drama|Thriller
# 39             Action|Adventure|Drama
# 40                Adventure|Drama|War
# 41  Action|Adventure|Comedy|Drama|War
# 42                    Adventure|Drama
# 43      Action|Adventure|Comedy|Drama
# 44             Action|Adventure|Drama
# 45               Adventure|Drama|IMAX
# 46                   Action|Adventure
# 47             Adventure|Comedy|Drama
# 48             Action|Adventure|Drama
# 49             Action|Adventure|Drama

# %% [markdown]
# # Predict de um item baseado em outro item

# %%
# gerar o feature vector do subset des filmes
input_item_m = keras.layers.Input(shape=(num_item_features,))
vm_m = item_NN(input_item_m)
vm_m = keras.layers.LayerNormalization(axis=1)(vm_m)
model_m = keras.Model(input_item_m, vm_m)

scaled_item_vecs = scalerItem.transform(item_vecs)
vms = model_m.predict(scaled_item_vecs[:,item_columns_start:])

count = 50  # quantidade de filmes para mostrar
dim = len(vms)
dist = np.zeros((dim,dim))

# calcular proximidade entre os feature vectors usando square distance
for i in range(dim):
    for j in range(dim):
        dist[i,j] = sq_dist(vms[i, :], vms[j, :])

m_dist = ma.masked_array(dist, mask=np.identity(dist.shape[0]))

disp = [["movie1", "genres", "movie2", "genres"]]
for i in range(count):
    min_idx = np.argmin(m_dist[i])
    movie1_id = int(np.ceil(abs(item_train[i,0])))
    movie2_id = int(np.ceil(abs(item_train[min_idx,0])))
    disp.append( [movies_dict[movie1_id]['title'], movies_dict[movie1_id]['genres'],
                  movies_dict[movie2_id]['title'], movies_dict[movie1_id]['genres']]
               )
print(disp)
# Out:
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# [['movie1', 'genres', 'movie2', 'genres'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Grumpier Old Men (1995)', 'Comedy|Romance', 'Toy Story (1995)', 'Comedy|Romance'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Jumanji (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Jumanji (1995)', 'Adventure|Children|Fantasy', 'Toy Story (1995)', 'Adventure|Children|Fantasy'], ['Jumanji (1995)', 'Adventure|Children|Fantasy', 'Toy Story (1995)', 'Adventure|Children|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Jumanji (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Grumpier Old Men (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Jumanji (1995)', 'Adventure|Children|Fantasy', 'Toy Story (1995)', 'Adventure|Children|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Jumanji (1995)', 'Adventure|Children|Fantasy', 'Toy Story (1995)', 'Adventure|Children|Fantasy'], ['Jumanji (1995)', 'Adventure|Children|Fantasy', 'Toy Story (1995)', 'Adventure|Children|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Jumanji (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Grumpier Old Men (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Jumanji (1995)', 'Adventure|Children|Fantasy', 'Jumanji (1995)', 'Adventure|Children|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], [' ...
